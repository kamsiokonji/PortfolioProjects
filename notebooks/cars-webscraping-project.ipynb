# %% [markdown]
# In this project, we use webscraping packages to scrape data from cars.com website.

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# HTTP requests
url = "https://www.cars.com/shopping/results/?dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=30&mileage_max=&page_size=20&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip="

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.26"
}

page = requests.get(url, headers=headers)

# checking status code
page.status_code
# Out:
# 200

# %%
# soup object
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">
#    Certified Used Mercedes-Benz for Sale | Cars.com
#   </title>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,088 Mercedes-Benz models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Certified Used Mercedes-Benz for Sale | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,088 Mercedes-Benz models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Certified Used Mercedes-Benz for Sale | Cars.com" name="twitter:title"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,088 Mercedes-Benz models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">
#    {"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}
#   </script>
# <style>
#    a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizi ...
#   </style>
# <style>
#    .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{border:1px solid #e6e6e6;box-shadow:inset 0 -1px 0 0 #e6e6e6;height:520px;margin-bottom:24px;position:relative;width:100%}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;flex-direction:column;height:272px;overflow:hidden;position:relative;width:100%}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;height:265px;justify-content:space-between}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{color:#fff;font-size:11px;font-style:italic;left:10px;position:absolute;top:32px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{height:55px;position:absolute;right:12px;top:10px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 45%;height:175px;position:relative;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;padding-top:52px;position:inherit}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{left:11%;max-width:80%;padding-top:0;position:absolute;top:30%}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:flex-end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{flex:1 1 50%;margin:16px 8px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{flex:1 1 50%;margin:16px 16px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4 ...
#   </style>
# <script defer="" src="/13a7a7c2587552357060/js/app.js?vsn=d">
# </script>
# <script id="datadog-config" type="application/json">
#    {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "version": "b33460143cff3c9e88ba67459919d3400ed16dd5",
#         "sampleRate": 2,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
#   </script>
# <script id="datadog-global-context" type="application/json">
#    {"env":"production","trip_id":""}
#   </script>
# <meta content="Nh48Jzw4KhAcHRE6PA0WPlosKzAjZyMqZuWlRlXRUnujEDGjcIOeKVdP" name="csrf-token"/>
# <script>
#    bazadebezolkohpepadr="242818892"
#   </script>
# <script defer="" src="https://www.cars.com/akam/13/e791d1f" type="text/javascript">
# </script>
# </head>
# <div hidden="">
# <span id="new-tab-link">
#    Opens website in a new tab
#   </span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/">
# <img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/>
# </a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link">
# <a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">
#           Cars for Sale
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">
#           Research &amp; Reviews
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">
#           News &amp; Videos
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">
#           Sell Your Car
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">
#           Service &amp; Repair
#          </a>
# </li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger">
# </ep-svg>
# <span class="nav-user-name">
#          Menu
#         </span>
# <span class="menu-text">
#          Menu
#         </span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/shopping/results/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
#          Menu
#         </span>
# <span class="menu-text">
#          Menu
#         </span>
# </div>
# <ul class="menu-links">
# <li class="header-link">
# <a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">
#           Cars for Sale
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">
#           Research &amp; Reviews
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">
#           News &amp; Videos
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">
#           Sell Your Car
#          </a>
# </li>
# <li class="header-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">
#           Service &amp; Repair
#          </a>
# </li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/">
# <ep-svg library="cars" name="heart-empty">
# </ep-svg>
#           Saved Cars
#          </a>
# </li>
# <li class="profile-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/">
# <ep-svg library="cars" name="search">
# </ep-svg>
#           Saved Searches
#          </a>
# </li>
# <li class="profile-link">
# <a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/">
# <ep-svg library="cars" name="tag">
# </ep-svg>
#           Your Garage
#          </a>
# </li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Fdealer_id%3D%26keyword%3D%26list_price_max%3D%26list_price_min%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D30%26mileage_max%3D%26page_size%3D20%26sort%3Dbest_match_desc%26stock_type%3Dcpo%26year_max%3D%26year_min%3D%26zip%3D">
#          Sign in
#         </a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Fdealer_id%3D%26keyword%3D%26list_price_max%3D%26list_price_min%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D30%26mileage_max%3D%26page_size%3D20%26sort%3Dbest_match_desc%26stock_type%3Dcpo%26year_max%3D%26year_min%3D%26zip%3D">
#          Create an account
#         </a>
# </div>
# </ep-modal>
# </section>
# </header>
# <template>
# <cars-auth-modal csrftoken="Nh48Jzw4KhAcHRE6PA0WPlosKzAjZyMqZuWlRlXRUnujEDGjcIOeKVdP" forgotpasswordpath="/forgot_password/" open="" redirectpath="/shopping/results/?dealer_id=&amp;keyword=&amp;list_price_max=&amp;list_price_min=&amp;makes%5B%5D=mercedes_benz&amp;maximum_distance=30&amp;mileage_max=&amp;page_size=20&amp;sort=best_match_desc&amp;stock_type=cpo&amp;year_max=&amp;year_min=&amp;zip=" type="sign_up">
# <div slot="disclaimer">
# <div class="sds-disclaimer">
#         By signing up, you agree to our
#         <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">
#          Privacy Statement
#         </a>
#         and
#         <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">
#          Terms of Service
#         </a>
#         .
#        </div>
# </div>
# <div class="social-slot" slot="social">
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Fdealer_id%3D%26keyword%3D%26list_price_max%3D%26list_price_min%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D30%26mileage_max%3D%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26sort%3Dbest_match_desc%26stock_type%3Dcpo%26year_max%3D%26year_min%3D%26zip%3D">
# <ep-svg library="social" name="facebook">
# </ep-svg>
#           Sign in with Facebook
#          </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Fdealer_id%3D%26keyword%3D%26list_price_max%3D%26list_price_min%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D30%26mileage_max%3D%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26sort%3Dbest_match_desc%26stock_type%3Dcpo%26year_max%3D%26year_min%3D%26zip%3D">
# <ep-svg library="social" name="google">
# </ep-svg>
#           Sign in with Google
#          </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-apple" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Fdealer_id%3D%26keyword%3D%26list_price_max%3D%26list_price_min%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D30%26mileage_max%3D%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dapple%26sort%3Dbest_match_desc%26stock_type%3Dcpo%26year_max%3D%26year_min%3D%26zip%3D">
# <ep-svg library="social" name="apple">
# </ep-svg>
#           Sign in with Apple
#          </a>
# </li>
# </ul>
# </div>
# <div class="sds-field" slot="emailField">
# <div class="sds-input-container">
# <input autocomplete="email" class="sds-text-field" id="auth-modal-email" maxlength="255" placeholder=" " required="" type="email"/>
# <label class="sds-label" for="auth-modal-email">
#          Email
#         </label>
# </div>
# <span class="sds-helper-text">
# </span>
# </div>
# <div class="sds-field" slot="newAccountEmailField">
# <div class="sds-input-container disabled">
# <input autocomplete="email" class="sds-text-field" disabled="" id="auth-modal-email2" maxlength="255" placeholder=" " type="email"/>
# <label class="sds-label" for="auth-modal-email2">
#          Email
#         </label>
# </div>
# <span class="sds-helper-text">
# </span>
# </div>
# <div class="sds-field" slot="currentPasswordField">
# <div class="sds-input-container">
# <input autocomplete="current-password" class="sds-text-field" id="auth-modal-current-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-current-password">
#          Password
#         </label>
# </div>
# <span class="sds-helper-text">
#         Enter a minimum of 8 characters.
#        </span>
# </div>
# <div class="sds-field" slot="newPasswordField">
# <div class="sds-input-container">
# <input autocomplete="new-password" class="sds-text-field" id="auth-modal-new-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-new-password">
#          Password
#         </label>
# </div>
# <span class="sds-helper-text">
#         Enter a minimum of 8 characters.
#        </span>
# </div>
# <div class="sds-field" slot="firstNameField">
# <div class="sds-input-container">
# <input autocomplete="given-name" class="sds-text-field" id="auth-modal-first-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-first-name">
#          First name
#         </label>
# </div>
# <span class="sds-helper-text">
# </span>
# </div>
# <div class="sds-field" slot="lastNameField">
# <div class="sds-input-container">
# <input autocomplete="family-name" class="sds-text-field" id="auth-modal-last-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-last-name">
#          Last name
#         </label>
# </div>
# <span class="sds-helper-text">
# </span>
# </div>
# </cars-auth-modal>
# </template>
# </cars-global-header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here">
# </div>
# <div data-phx-main="true" data-phx-session="SFMyNTY.....MVIpr5I4nylcwRwbekPr3W4MYaC9mEWYHrGCvUnoR_o" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeVhrN1B4REZyUE0xWWtobgYA6fcBXIQBYgABUYA.eIGQaMJQzSkojF9BQPTlKdeWsLTZH_ftF_cJWM1HO64" id="phx-FyXk7PxDFrPM1Ykh">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/LiMxE2PN24JtmR9d80uA95hYezw.jpg" rel="preload"/>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="LeadForm" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close">
# </use>
# </svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section--">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">
#           Contact seller
#          </h2>
# </header>
# </div>
# <div class="lead-form" id="lead-form-container-">
# <form action="#" data-index="" data-reset-activity-limit-for="email-lead-error--inline" id="fields-srp-lead-form-modal" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#srp-lead-form-modal">
# <input name="_csrf_token" type="hidden" value="Nh48Jzw4KhAcHRE6PA0WPlosKzAjZyMqZuWlRlXRUnujEDGjcIOeKVdP"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error--inline" data-errorname="email-lead-error--inline" data-index="">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-">
#                 First name
#                </label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-">
#                 Last name
#                </label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-">
#                 Email
#                </label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-">
#                 Phone (optional)
#                </label>
# </div>
# </div>
# <input id="subject-modal-" name="lead[subject]" type="hidden" value="Ask a question"/>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# </textarea>
# <label class="sds-label" for="comments-modal-">
#                 Comments
#                </label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in hidden">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#srp-lead-form-modal">
# <input class="sds-input" id="trade-in-checkbox-srp-lead-form-modal" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-srp-lead-form-modal">
#                 I have a trade in
#                </label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-srp-lead-form-modal_make_select-modal-" name="lead[trade_in][make]">
# <optgroup label="">
# <option selected="" value="">
#                    Choose a make
#                   </option>
# <option value="ac">
#                    AC
#                   </option>
# <option value="acura">
#                    Acura
#                   </option>
# <option value="alfa_romeo">
#                    Alfa Romeo
#                   </option>
# <option value="american_motors">
#                    American Motors
#                   </option>
# <option value="am_general">
#                    Am General
#                   </option>
# <option value="aston_martin">
#                    Aston Martin
#                   </option>
# <option value="auburn">
#                    Auburn
#                   </option>
# <option value="audi">
#                    Audi
#                   </option>
# <option value="austin">
#                    Austin
#                   </option>
# <option value="austin_healey">
#                    Austin-Healey
#                   </option>
# <option value="avanti_motors">
#                    Avanti Motors
#                   </option>
# <option value="bentley">
#                    Bentley
#                   </option>
# <option value="bmw">
#                    BMW
#                   </option>
# <option value="bricklin">
#                    Bricklin
#                   </option>
# <option value="bugatti">
#                    Bugatti
#                   </option>
# <option value="buick">
#                    Buick
#                   </option>
# <option value="cadillac">
#                    Cadillac
#                   </option>
# <option value="checker">
#                    Checker
#                   </option>
# <option value="chevrolet">
#                    Chevrolet
#                   </option>
# <option value="chrysler">
#                    Chrysler
#                   </option>
# <option value="citroen">
#                    Citroen
#                   </option>
# <option value="daewoo">
#                    Daewoo
#                   </option>
# <option value="daihatsu">
#                    Daihatsu
#                   </option>
# <option value="datsun">
#                    Datsun
#                   </option>
# <option value="delahaye">
#                    Delahaye
#                   </option>
# <option value="delorean">
#                    Delorean
#                   </option>
# <option value="desoto">
#                    Desoto
#                   </option>
# <option value="detomaso">
#                    DeTomaso
#                   </option>
# <option value="dodge">
#                    Dodge
#                   </option>
# <option value="eagle">
#                    Eagle
#                   </option>
# <option value="edsel">
#                    Edsel
#                   </option>
# <option value="essex">
#                    Essex
#                   </option>
# <option value="ferrari">
#                    Ferrari
#                   </option>
# <option value="fiat">
#                    FIAT
#                   </option>
# <option value="fisker">
#                    Fisker
#                   </option>
# <option value="ford">
#                    Ford
#                   </option>
# <option value="franklin">
#                    Franklin
#                   </option>
# <option value="genesis">
#                    Genesis
#                   </option>
# <option value="geo">
#                    Geo
#                   </option>
# <option value="gmc">
#                    GMC
#                   </option>
# <option value="honda">
#                    Honda
#                   </option>
# <option value="hudson">
#                    Hudson
#                   </option>
# <option value="hummer">
#                    Hummer
#                   </option>
# <option value="hupmobile">
#                    Hupmobile
#                   </option>
# <option value="hyundai">
#                    Hyundai
#                   </option>
# <option value="infiniti">
#                    INFINITI
#                   </option>
# <option value="international">
#                    International
#                   </option>
# <option value="isuzu">
#                    Isuzu
#                   </option>
# <option value="jaguar">
#                    Jaguar
#                   </option>
# <option value="jeep">
#                    Jeep
#                   </option>
# <option value="jensen">
#                    Jensen
#                   </option>
# <option value="kaiser">
#                    Kaiser
#                   </option>
# <option value="karma">
#                    Karma
#                   </option>
# <option value="kia">
#                    Kia
#                   </option>
# <option value="koenigsegg">
#                    Koenigsegg
#                   </option>
# <option value="lamborghini">
#                    Lamborghini
#                   </option>
# <option value="lancia">
#                    Lancia
#                   </option>
# <option value="land_rover">
#                    Land Rover
#                   </option>
# <option value="lasalle">
#                    LaSalle
#                   </option>
# <option value="lexus">
#                    Lexus
#                   </option>
# <option value="lincoln">
#                    Lincoln
#                   </option>
# <option value="lotus">
#                    Lotus
#                   </option>
# <option value="lucid">
#                    Lucid
#                   </option>
# <option value="maserati">
#                    Maserati
#                   </option>
# <option value="maybach">
#                    Maybach
#                   </option>
# <option value="mazda">
#                    Mazda
#                   </option>
# <option value="mclaren">
#                    McLaren
#                   </option>
# <option value="mercedes_benz">
#                    Mercedes-Benz
#                   </option>
# <option value="mercury">
#                    Mercury
#                   </option>
# <option value="merkur">
#                    Merkur
#                   </option>
# <option value="mg">
#                    MG
#                   </option>
# <option value="mini">
#                    MINI
#                   </option>
# <option value="mitsubishi">
#                    Mitsubishi
#                   </option>
# <option value="morgan">
#                    Morgan
#                   </option>
# <option value="morris">
#                    Morris
#                   </option>
# <option value="nash">
#                    Nash
#                   </option>
# <option value="nissan">
#                    Nissan
#                   </option>
# <option value="oldsmobile">
#                    Oldsmobile
#                   </option>
# <option value="opel">
#                    Opel
#                   </option>
# <option value="packard">
#                    Packard
#                   </option>
# <option value="pagani">
#                    Pagani
#                   </option>
# <option value="panoz">
#                    Panoz
#                   </option>
# <option value="peugeot">
#                    Peugeot
#                   </option>
# <option value="plymouth">
#                    Plymouth
#                   </option>
# <option value="polestar">
#                    Polestar
#                   </option>
# <option value="pontiac">
#                    Pontiac
#                   </option>
# <option value="porsche">
#                    Porsche
#                   </option>
# <option value="qvale">
#                    Qvale
#                   </option>
# <option value="ram">
#                    RAM
#                   </option>
# <option value="renault">
#                    Renault
#                   </option>
# <option value="rivian">
#                    Rivian
#                   </option>
# <option value="rolls_royce">
#                    Rolls-Royce
#                   </option>
# <option value="rover">
#                    Rover
#                   </option>
# <option value="saab">
#                    Saab
#                   </option>
# <option value="saleen">
#                    Saleen
#                   </option>
# <option value="saturn">
#                    Saturn
#                   </option>
# <option value="scion">
#                    Scion
#                   </option>
# <option value="smart">
#                    smart
#                   </option>
# <option value="spyker">
#                    Spyker
#                   </option>
# <option value="sterling">
#                    Sterling
#                   </option>
# <option value="studebaker">
#                    Studebaker
#                   </option>
# <option value="subaru">
#                    Subaru
#                   </option>
# <option value="sunbeam">
#                    Sunbeam
#                   </option>
# <option value="suzuki">
#                    Suzuki
#                   </option>
# <option value="tesla">
#                    Tesla
#                   </option>
# <option value="toyota">
#                    Toyota
#                   </option>
# <option value="triumph">
#                    Triumph
#                   </option>
# <option value="tvr">
#                    TVR
#                   </option>
# <option value="volkswagen">
#                    Volkswagen
#                   </option>
# <option value="volvo">
#                    Volvo
#                   </option>
# <option value="willys">
#                    Willys
#                   </option>
# <option value="yugo">
#                    Yugo
#                   </option>
# </optgroup>
# </select>
# <label class="sds-label" for="make_select-modal-">
#                  Make
#                 </label>
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down">
# </use>
# </svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_model_select-modal-" name="lead[trade_in][model]">
# <optgroup label="">
# <option selected="" value="">
#                    Choose a model
#                   </option>
# </optgroup>
# </select>
# <label class="sds-label" for="model_select-modal-">
#                  Model
#                 </label>
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down">
# </use>
# </svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_year_select-modal-" name="lead[trade_in][year]">
# <optgroup label="">
# <option selected="" value="">
#                    Choose a year
#                   </option>
# </optgroup>
# </select>
# <label class="sds-label" for="year_select-modal-">
#                  Year
#                 </label>
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down">
# </use>
# </svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-">
#                  Exterior color
#                 </label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-">
#                  Mileage
#                 </label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-">
#                  VIN (optional)
#                 </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" type="submit">
#              Contact seller
#             </button>
# </div>
# <small class="sds-disclaimer">
# <p>
#              By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#             </p>
# <p>
#              We value your privacy.
#              <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">
#               Cars.com Privacy Statement
#              </a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#srp-lead-form-modal" phx_value_cid="srp-lead-form-modal">
# </div>
# <div phx-hook="LeadFormPositionAdjustments">
# </div>
# <div>
# </div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-props='{"selected_refinement":null}' data-search-instance-id="bb755bae-4d15-42d3-b827-0493df5659bf" data-search-type="general-inventory-search" data-site-activity='{"search_transmissions":"","search_model_groups":"","dealerSearchType":"multiple_dealers","search_zip":"","search_makes":"mercedes_benz","model_group":"mercedes_benz-c_all","seoTemplateType":null,"search_features":"","exterior_color":"","bodystyle":"","transmission":"","result_page_number":1,"seller_type":"","search_interior_colors":"","sort_field":"searchRank1","search_contactless_services":"","search_trims":"","make":"","search_instance_id":"","search_max_year":"","result_page_count":105,"search_deal_ratings":"","search_make_model_groups":"","search_keyword":"","canonical_mmt":"","search_stock_sub":"","searchCategory":"results","features":"","search_exterior_colors":"","search_make_model_trims":[{"make":"mercedes_benz"}],"search_results_on_page":21,"listing_ids":["61215756-d32d-420f-b367-d9ae67413a5e","57152a50-6efe-4a1b-9a15-dd4f1bc232b0","a52d4b75-b606-4457-bfc8-bf6b7192af40","fc62dd6a-488f-44bb-b536-3fc6f74808b9","7df034ec-234c-48ec-ac19-d5e0807ecfc9","e4986320-85ed-4f49-9ba0-75ed746b978e","48e5be96-e8d8-47d0-bf01-e673debc0950","c70eda83-b851-4d23-a743-8ac6a88601bc","eefc7a3e-0f10-4dad-bb1c-a6f5cb02c1b0","c17e0a42-eed1-40f6-9081-bb22fde0e970","ce285baf-d4a4-4673-93a5-0133886e0d4e","d0712285-e610-4493-8b61-f125948e8938","ad6531b9-3062-451c-824c-2c64db390137","e15d620d-bcff-466f-a528-de91c0d841fc","0de19b30-bf4a-4ae9-aae2-be157e6c8590","db64302a-fdb2-4634-82e0-b81cba2e6dbc","8ae96773-878d-4992-9bab-c532896fbc6b","4541461c-d53f-4245-afbc-4ee4e904b89c","c72afef8-5d19-4263-a199-d53712b45b9c","73c7586e-a290-4707-9417-21305eb458a3","d30b88fd-2702-44b3-bfff-b32623b24e87"],"trip_id":null,"interiorColor":"","search_fuel_types":"","sort_order":"desc","search_min_year":"","price":"","search_drivetrains":"","stock_type":"","search_bodystyles":"","filter_category_value":"","search_max_price":"","multipleVehicles":true,"search_stock_type_standard":"used","search_door_counts":"","result_per_page":20,"search_stock_type":"cpo","search_mileage_max":"","search_cylinder_counts":"","total_results":2088,"search_models":"","cat":"multi_cats","resultsType":"not_modified","search_cab_types":"","search_seller_types":"","search_min_price":"","fuel_type":"","cpo_indicator":true,"search_make_models":"","search_only_with_photos":null,"vehicleArray":[{"badges":["great_deal","virtual_appt","home_delivery","cpo"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:CLA 250:Base 4MATIC","cat":"luxurypassenger_standard","certified_preowned":true,"cpo_indicator":true,"customer_id":"5387852","exterior_color":"Mojave Silver Metallic","fuel_type":"Gasoline","listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"Mercedes-Benz","mileage":"17266","model":"CLA 250","msrp":"43995","nvi_program":false,"price":"38888","seller_type":"dealership","sponsored":true,"sponsored_type":"inventory_ad","stock_sub":"","stock_type":"Used","trim":"Base 4MATIC","vin":"W1K5J4HB5LN108885","year":"2020"},{"badges":["great_deal","virtual_appt","home_delivery","cpo"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:AMG A 35:Base","cat":"luxurypassenger_standard","certified_preowned":true,"cpo_indicator":true,"customer_id":"109599","exterior_color":"Cosmos Black Metallic","fuel_type":"Gasoline","listing_id":"57152a50-6efe-4a1b-9a15-dd4f1bc232b0","make":"Mercedes-Benz","mileage":"9401","model":"AMG A 35","msrp":"48762","nvi_program":false,"price":"48762","seller_type":"dealership","sponsored":true,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Base","vin":"W1K3G5BB0MJ312829","year":"2021"},{"badges":["cpo"],"bodystyle":"SUV","canonical_mmt":"Mercedes-Benz:G-Class:G 550 4MATIC","cat":"luxurysuv_suv","certified_preowned":true,"cpo_indicator":true,"customer_id":"156920","exterior_color":"White","f ...
# <script type="application/ld+json">
#       {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2021 Mercedes-Benz AMG A 35 Base","position":1,"url":"https://www.cars.com/vehicledetail/57152a50-6efe-4a1b-9a15-dd4f1bc232b0//"},{"@type":"ListItem","name":"2019 Mercedes-Benz G-Class G 550 4MATIC","position":2,"url":"https://www.cars.com/vehicledetail/a52d4b75-b606-4457-bfc8-bf6b7192af40//"},{"@type":"ListItem","name":"2021 Mercedes-Benz AMG GLE 53 Base","position":3,"url":"https://www.cars.com/vehicledetail/fc62dd6a-488f-44bb-b536-3fc6f74808b9//"},{"@type":"ListItem","name":"2020 Mercedes-Benz S-Class S 560 4MATIC","position":4,"url":"https://www.cars.com/vehicledetail/7df034ec-234c-48ec-ac19-d5e0807ecfc9//"},{"@type":"ListItem","name":"2017 Mercedes-Benz AMG GLC 43 Base 4MATIC","position":5,"url":"https://www.cars.com/vehicledetail/e4986320-85ed-4f49-9ba0-75ed746b978e//"},{"@type":"ListItem","name":"2017 Mercedes-Benz AMG CLA 45 Base 4MATIC","position":6,"url":"https://www.cars.com/vehicledetail/48e5be96-e8d8-47d0-bf01-e673debc0950//"},{"@type":"ListItem","name":"2018 Mercedes-Benz G-Class G 550 4MATIC","position":7,"url":"https://www.cars.com/vehicledetail/c70eda83-b851-4d23-a743-8ac6a88601bc//"},{"@type":"ListItem","name":"2022 Mercedes-Benz GLB 250 4MATIC","position":8,"url":"https://www.cars.com/vehicledetail/eefc7a3e-0f10-4dad-bb1c-a6f5cb02c1b0//"},{"@type":"ListItem","name":"2021 Mercedes-Benz S-Class S 580 4MATIC","position":9,"url":"https://www.cars.com/vehicledetail/c17e0a42-eed1-40f6-9081-bb22fde0e970//"},{"@type":"ListItem","name":"2020 Mercedes-Benz Maybach S 560 4MATIC","position":10,"url":"https://www.cars.com/vehicledetail/ce285baf-d4a4-4673-93a5-0133886e0d4e//"},{"@type":"ListItem","name":"2018 Mercedes-Benz AMG S 65 Base","position":11,"url":"https://www.cars.com/vehicledetail/d0712285-e610-4493-8b61-f125948e8938//"},{"@type":"ListItem","name":"2021 Mercedes-Benz AMG GLE 53 Base","position":12,"url":"https://www.cars.com/vehicledetail/ad6531b9-3062-451c-824c-2c64db390137//"},{"@type":"ListItem","name":"2019 Mercedes-Benz CLS 450 Base","position":13,"url":"https://www.cars.com/vehicledetail/e15d620d-bcff-466f-a528-de91c0d841fc//"},{"@type":"ListItem","name":"2020 Mercedes-Benz GLS 450 Base 4MATIC","position":14,"url":"https://www.cars.com/vehicledetail/0de19b30-bf4a-4ae9-aae2-be157e6c8590//"},{"@type":"ListItem","name":"2021 Mercedes-Benz GLB 250 Base 4MATIC","position":15,"url":"https://www.cars.com/vehicledetail/db64302a-fdb2-4634-82e0-b81cba2e6dbc//"},{"@type":"ListItem","name":"2022 Mercedes-Benz GLB 250 Base 4MATIC","position":16,"url":"https://www.cars.com/vehicledetail/8ae96773-878d-4992-9bab-c532896fbc6b//"},{"@type":"ListItem","name":"2021 Mercedes-Benz AMG GLC 43 4MATIC Coupe","position":17,"url":"https://www.cars.com/vehicledetail/4541461c-d53f-4245-afbc-4ee4e904b89c//"},{"@type":"ListItem","name":"2019 Mercedes-Benz AMG C 43 Base 4MATIC","position":18,"url":"https://www.cars.com/vehicledetail/c72afef8-5d19-4263-a199-d53712b45b9c//"},{"@type":"ListItem","name":"2017 Mercedes-Benz CLS 550 Base 4MATIC","position":19,"url":"https://www.cars.com/vehicledetail/73c7586e-a290-4707-9417-21305eb458a3//"},{"@type":"ListItem","name":"2021 Mercedes-Benz AMG GLE 63 S-Model 4MATIC","position":20,"url":"https://www.cars.com/vehicledetail/d30b88fd-2702-44b3-bfff-b32623b24e87//"}],"itemListOrder":"https://schema.org/ItemListUnordered","numberOfItems":20}
#      </script>
# <script type="application/ld+json">
# ...
#           DealerRater
#           <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">
#           FUEL
#           <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">
#           Auto.com
#           <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">
#           NewCars.com
#           <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">
#           Pickuptrucks.com
#           <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">
#        Our Company
#       </span>
# <svg class="accordion-section-icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down">
# </use>
# </svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">
#          About Cars.com
#         </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">
#          Contact Cars.com
#         </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">
#          Investor Relations
#          <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">
#          Careers
#         </a>
# </li>
# <li>
# <a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">
#          Licensing &amp; Reprints
#          <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">
#          Site Map
#         </a>
# </li>
# <li>
# <a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">
#          Feedback
#         </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">
#        Our Mobile App
#       </span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">
#        Download the App Today
#       </a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">
#        Connect With Us
#       </span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link">
# <a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter">
# </use>
# </svg>
# </a>
# </li>
# <li class="social-link">
# <a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook">
# </use>
# </svg>
# </a>
# </li>
# <li class="social-link">
# <a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube">
# </use>
# </svg>
# </a>
# </li>
# <li class="social-link">
# <a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram">
# </use>
# </svg>
# </a>
# </li>
# <li class="social-link">
# <a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin">
# </use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">
#         Terms of Service
#        </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">
#         Privacy Statement
#        </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">
#         Do Not Sell My Personal Information
#        </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">
#         Accessibility Statement
#        </a>
# </li>
# <li>
# <a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">
#         Ad Choices
#        </a>
# </li>
# </ul>
# <div class="global-copyright-copy">
#       ©
# 2022 Cars.com. All rights reserved.
#      </div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close">
# </use>
# </svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px">
# </iframe>
# </div>
# </div>
# </footer>
# <script src="">
# </script>
# <link data-href="/13a7a7c2587552357060/css/common.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="/13a7a7c2587552357060/css/srp.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#     window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"zip_ip2geo":null,"page_channel":"shopping","utm_medium":null,"page_type":"shopping/search-results","profileAccountType":null,"url_base":"","customer_id":"","aff_code":"national","bodystyle":null,"url_referer":"","make":"","page_name":"shopping/search-results","platform_id":"cars_responsive","loginStatus":false,"utm_source":null,"useragent":"","lat_long":"/","local_zone":null,"facebook_event_id":"dHJpcF9pZD00OTAzNWU0NS0zZTAwLTRmZDgtODNhNS0wMTE1ZmM3N2RkZjEmdHM9MTY2Nzk5MDk0MzQ5NA==","trip_id":"","seller_id":null,"utm_content":null,"utm_campaign":null,"page_key":"search-results","cat":null,"year":"","page_detail":null,"designated_market_area_key":null,"marketing_click_data":null,"utm_term":null,"market_name":null,"marketing_referral_source":"","marketing_click_id":"","model":"","user_state":"anonymous"}
#    </script>
# <script>
#     window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"is_bot":true,"als_private_data":"QTEyOEdDTQ.GRZRG-BJwuKncZ1cEcKmsdwVHGnpn_Fi9ds29lEr6PB8tNL7anqSoUXVW-U.WvIlhSaxD4zUhfU4.dehQW4B55ZT92h83JWrHACIhfho1OSH3AI3Y8FeUt5W01s9n0jci92TzDzdvznDG0kMrmQ.DGM7uJFDE0BpmA2BuHyzPg","utm_medium":null,"device_os":null,"content_slug":"","carrier":null,"model_year":"","vertical_position":"","results_page_number":1,"msrp":"","customer_id":"","app_version":null,"upsells":[],"aff_code":"national","bodystyle":"","x_forwarded_for":null,"trim":"","search_zipcode":"","page_instance_id":"FyXk7PjsHMbrzNUB05WC","experiment_ids":[{"index":0,"name":"ab_test_2_srp_hp_prod"},{"analytics":{"payload":{"pe":"tnt","tnta":"188232:1:0|0,188232:1:0|2,188232:1:0|1"}},"index":1,"name":"ab_test_14_srp_prod","options":[{"responseTokens":{"activity.id":"188232","activity.name":"Prod | Cars Web | AB Test 14 | SRP | All Visitors","experience.id":"1","experience.name":"Experience B","profile.activeActivities":"188232","profile.fourGroups":"GroupC","profile.twentyGroups":"Group4","profile.twoGroups":"GroupA"},"sourceType":"target"}]}],"make":"","search_instance_id":null,"profile_user_id":null,"ga_client_id":null,"web_page_type_to":"shopping/search-results","platform_id":"cars_responsive","utm_source":null,"useragent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.26","facebook_event_id":"dHJpcF9pZD00OTAzNWU0NS0zZTAwLTRmZDgtODNhNS0wMTE1ZmM3N2RkZjEmdHM9MTY2Nzk5MDk0MzQ5NA==","trip_id":"","lead_event_id":null,"referer_url":"","internet_connection":null,"roxanne_visit_id":"","marketing_click_source":"","price":null,"external_uuids":null,"horizontal_position":"","seller_id":null,"stock_type":"","device_id":null,"device_type":"desktop","utm_content":null,"results_page_count":105,"utm_campaign":null,"finance_application_id":null,"longitude":null,"bot_type":"Unknown Bot (B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;High-Velocity-BOT:100:aggressive","facebook_event_intent_id":"capi_viv_event","total_results":2088,"adobe_id":null,"roxanne_visitor_id":"","results_per_page":20,"iframe_location":"","device_model":null,"cpo_indicator":true,"utm_term":null,"latitude":null,"incentive_ids":"","marketing_click_id":"","page_url":"https://www.cars.com/shopping/results/?dealer_id=&amp;keyword=&amp;list_price_max=&amp;list_price_min=&amp;makes[]=mercedes_benz&amp;maximum_distance=30&amp;mileage_max=&amp;page_size=20&amp;sort=best_match_desc&amp;stock_type=cpo&amp;year_max=&amp;year_min=&amp;zip=","model":"","web_page_type_from":"","listing_id":"","pdid":null,"timestamp_utc":1667990943873}
#    </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js">
# </script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
#    </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js" id="adobe-launch-script">
# </script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js">
# </script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer="">
# </script>
# <script>
#     window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#    </script>
# <div data-id="188232:1:0|0,188232:1:0|2,188232:1:0|1" hidden="" id="tnta-options">
# </div>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#    </script>
# <noscript>
# <img src="https://www.cars.com/akam/13/pixel_e791d1f?a=dD00NWQ5MGUyOWQ3OTgyNjQzZDI4OTU5NmIxMmQzYzg5NTU4OGFiOGYyJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
# </noscript>
# <script src="/EAi3ht/7Nz/eYa/hVP8wMS4/5EQ94tztS9zE/LncmMxobXQI/FWYrS/xVrMG0B" type="text/javascript">
# </script>
# </link>
# </body>
# </html>

# %%
# creating a results variable 
results = soup2.find_all("div", {"class": "vehicle-card"})
len(results)
# Out:
# 21

# %%
# printing the first data from the url
results[0]
# Out:
# <div class="vehicle-card inventory-ad" data-inventory-ad="true" data-koddi-click-tracking-url="https://cars.koddi.io/event-collection/beacon?action=click&amp;trackingData={trackingData}&amp;rank={rank}&amp;clientName=Cars&amp;beaconIssued=2022-11-09T10:49:03Z" data-koddi-impression-tracking-url="https://cars.koddi.io/event-collection/beacon?action=impression&amp;trackingData={trackingData}&amp;rank={rank}&amp;ts={ts}&amp;clientName=Cars&amp;beaconIssued=2022-11-09T10:49:03Z" data-koddi-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" data-koddi-tracking-data="..." data-koddi-tracking-guid="0a3da7cb-7670-4cf5-9a18-273577631f92" data-koddi-user-guid="" data-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-hook="VehicleCard" phx-target="6">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/61215756-d32d-420f-b367-d9ae67413a5e/" rel="nofollow" tabindex="-1">
# </a>
# <div class="inventory-ad-main vehicle-card-main">
# <div class="vehicle-card-photos">
# <a class="image-gallery-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-photo" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-photo"}' href="/vehicledetail/61215756-d32d-420f-b367-d9ae67413a5e/?attribution_type=isa" rel="nofollow">
# </a>
# <cars-filmstrip totalcount="27">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/LiMxE2PN24JtmR9d80uA95hYezw.jpg"/>
# </div>
# <div aria-label="Photo 2 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="1">
# <img alt="Photo 2 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/wrorCDPsYZfA1ClPB6SLhgmEJtE.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 3 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="2">
# <img alt="Photo 3 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/WolwFrgECMsOtJOpvU5cpG_wnQs.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 4 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="3">
# <img alt="Photo 4 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/LzotRJkZpJw6qeB3pddLdASCp2w.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 5 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="4">
# <img alt="Photo 5 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/uawa4GwSsQgtIMQxcrQgvhR1Bxo.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 6 of 27 of 2020 Mercedes-Benz CLA 250 Base 4MATIC" class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/55bb32ef-47e6-5414-8b60-3302fc288dbd/3cdd6686-e06e-471f-9636-43c5a5b3b125/D2gKRFgsc-vDyl6ExkOJk6ZI_Zw.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">
#                View all 27 photos
#               </div>
# </div>
# </div>
# </div>
# </cars-filmstrip>
# </div>
# <div class="vehicle-details">
# <a class="card-whitespace-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-whitespace" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-whitespace"}' href="/vehicledetail/61215756-d32d-420f-b367-d9ae67413a5e/?attribution_type=isa" phx-click="element_clicked" phx-target="6" phx-value-source="whitespace" rel="nofollow">
# </a>
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-1" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="85" phx-value-is_vdp="false" phx-value-listing_id="61215756-d32d-420f-b367-d9ae67413a5e">
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#heart">
# </use>
# </svg>
# <span class="text">
#               Save
#              </span>
# </button>
# </div>
# </div>
# <p class="stock-type">
#            Mercedes-Benz Certified
#           </p>
# <a class="vehicle-card-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-header" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-header"}' href="/vehicledetail/61215756-d32d-420f-b367-d9ae67413a5e/?attribution_type=isa" phx-click="element_clicked" phx-target="6" phx-value-source="title" rel="nofollow" target="">
# <h2 class="title">
#             2020 Mercedes-Benz CLA 250 Base 4MATIC
#            </h2>
# </a>
# <div class="mileage">
#            17,266 mi.
#           </div>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">
#             $38,888
#            </span>
# </div>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents="{&quot;cpo_badge&quot;:true,&quot;home_delivery_badge&quot;:true,&quot;price_badge&quot;:{&quot;price_badge&quot;:&quot;extremely competitively&quot;,&quot;price_badge_description&quot;:&quot;This car presents a great buying opportunity, priced at $5,072 under market. Our analysis compares this car's price, features, and condition with similar 2020 CLA 250s.&quot;,&quot;price_badge_savings_icon_text&quot;:&quot; | $5,072 under&quot;,&quot;price_badge_text&quot;:&quot;Great&quot;,&quot;price_badge_text_lowercase&quot;:&quot;great&quot;,&quot;price_savings_text&quot;:&quot; | $5,072 under&quot;,&quot;svg_tag&quot;:&quot;&lt;svg class=\&quot;sds-text-field__icon\&quot; height=\&quot;16\&quot; width=\&quot;16\&quot;&gt;&lt;use xlink:href=\&quot;/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-thick\&quot;&gt;&lt;/use&gt;&lt;/svg&gt;&quot;},&quot;virtual_appointments_badge&quot;:true,&quot;href_to_vdp&quot;:{&quot;href_to_vdp&quot;:&quot;/vehicledetail/61215756-d32d-420f-b367-d9ae67413a5e/?bodystyle=sedan&amp;cpo_indicator=true&amp;customer_id=5387852&amp;intent_id=badges-explainer&amp;listing_id=61215756-d32d-420f-b367-d9ae67413a5e&amp;make=mercedes_benz&amp;model=cla+250&amp;model_year=2020&amp;msrp=43995&amp;price=38888&amp;sponsored%3F=true&amp;stock_type=used&amp;trim=base+4matic&quot;}}" data-override-payload='{"bodystyle":"sedan","cpo_indicator":true,"customer_id":"5387852","horizontal_position":null,"listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"mercedes_benz","model":"cla 250","model_year":"2020","msrp":"43995","price":"38888","results_page_number":1,"sponsored?":true,"stock_type":"used","trim":"base 4matic","vertical_position":1,"web_page_type_from":"premier-module"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div aria-label="price_badge" class="sds-badge sds-badge--icon sds-badge--great js-price-badging" data-linkname="price-badge-great">
# <div class="sds-badge__icon">
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-thick">
# </use>
# </svg>
# </div>
# <span class="sds-badge__label">
#              Great Deal
#              <span class="sds-badge--price-savings">
#               | $5,072 under
#              </span>
# </span>
# </div>
# <div class="sds-badge sds-badge--cpo">
# <span class="sds-badge__label">
#              CPO Warrantied
#             </span>
# </div>
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">
#              Home Delivery
#             </span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">
#              Virtual Appointments
#             </span>
# </div>
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>
#              Mercedes-Benz of Temecula
#             </strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">
#              4.4
#             </span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
# </polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
# </polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
# </polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
# </polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--half">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <lineargradient id="linear" x1="0%" x2="100%" y1="0%" y2="0%">
# <stop offset="0%" stop-color="#532380">
# </stop>
# <stop offset="50%" stop-color="#532380">
# </stop>
# <stop offset="50%" stop-color="transparent">
# </stop>
# <stop offset="100%" stop-color="transparent">
# </stop>
# </lineargradient>
# </defs>
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
# </polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">
#              (1,396 reviews)
#             </span>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#             mi. from
#            </div>
# </div>
# <div class="sds-link--ext sds-button--link inventory_ad_deeplink" data-hidden-link-target="dealer-deeplink-61215756-d32d-420f-b367-d9ae67413a5e" id="nw2wr63hkn6qxqqcrucwtoufj5bamd4k" phx-hook="DealerDeeplinkInventoryAd" phx-target="#vehicle-card-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" role="link" tabindex="0">
# <span>
#             View on dealer's site
#            </span>
# <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </div>
# </div>
# <div class="contact-buttons" id="sponsored-61215756-d32d-420f-b367-d9ae67413a5e-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-dealer-phone" data-index="1" data-linkname="inventory-ad-dealer-phone" data-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" data-make="Mercedes-Benz" data-model="CLA 250" data-override-payload='{"bodystyle":"Sedan","customer_id":"5387852","external_uuids":{"koddi_fallback_id":"49035e45-3e00-4fd8-83a5-0115fc77ddf1"},"listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"Mercedes-Benz","model":"CLA 250","model_year":"2020","msrp":"43995","price":"38888","stock_type":"Used","vertical_position":1}' data-phone-number="9512251058" data-trim="Base 4MATIC" data-vim="W1K5J4HB5LN108885" data-year="2020" href="tel:+1-951-225-1058" id="dealer-phone-61215756-d32d-420f-b367-d9ae67413a5e" phx-click="call_button_clicked" phx-target="#vehicle-card-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-value-source="call_button">
#            Call
#           </a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-lead-form" data-dealer-customer-id="5387852" data-index="1" data-linkname="inventory-ad-lead-form" data-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" data-override-payload='{"bodystyle":"Sedan","customer_id":"5387852","external_uuids":{"koddi_fallback_id":"49035e45-3e00-4fd8-83a5-0115fc77ddf1"},"listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"Mercedes-Benz","model":"CLA 250","model_year":"2020","msrp":"43995","price":"38888","stock_type":"Used","vertical_position":1}' data-sponsored="true" data-sponsored-invariant="true" data-sponsored-type="inventory_ad" id="lead-form-email-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-click="check_availability_click" phx-hook="ShowLeadForm" phx-target="#vehicle-card-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-value-source="check_availability">
#            Check availability
#           </button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-lead-form" data-dealer-customer-id="5387852" data-index="1" data-linkname="inventory-ad-lead-form" data-listing-id="61215756-d32d-420f-b367-d9ae67413a5e" data-override-payload='{"bodystyle":"Sedan","customer_id":"5387852","external_uuids":{"koddi_fallback_id":"49035e45-3e00-4fd8-83a5-0115fc77ddf1"},"listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"Mercedes-Benz","model":"CLA 250","model_year":"2020","msrp":"43995","price":"38888","stock_type":"Used","vertical_position":1}' data-sponsored="true" data-sponsored-invariant="true" data-sponsored-type="inventory_ad" id="lead-form-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-click="check_availability_click" phx-hook="ShowLeadForm" phx-target="#vehicle-card-61215756-d32d-420f-b367-d9ae67413a5e-sponsored" phx-value-source="check_availability">
#            Check availability
#           </button>
# </div>
# <div class="hidden" data-connection-intent-id="inventory-ad-dealer-hyperlink" data-override-payload='{"bodystyle":"Sedan","customer_id":"5387852","external_uuids":{"koddi_fallback_id":"49035e45-3e00-4fd8-83a5-0115fc77ddf1"},"listing_id":"61215756-d32d-420f-b367-d9ae67413a5e","make":"Mercedes-Benz","model":"CLA 250","model_year":"2020","msrp":"43995","price":"38888","stock_type":"Used","vertical_position":1}'>
# <a aria-describedby="new-tab-link" aria-label="View on dealer's site, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="inventory-ad-dealer-hyperlink" href="https://www.mbtemecula.com/inventory/certified-used-2020-mercedes-benz-cla-cla-250-all-wheel-drive-4matic-coupe-w1k5j4hb5ln108885/?ctid=49035e45-3e00-4fd8-83a5-0115fc77ddf1&amp;lid=61215756-d32d-420f-b367-d9ae67413a5e&amp;utm_campaign=inventory_ads&amp;utm_medium=cpc&amp;utm_source=cars.com" id="dealer-deeplink-61215756-d32d-420f-b367-d9ae67413a5e" rel="noopener" target="_blank">
#            View on dealer's site
#            <svg class="sds-text-field__icon" height="16" width="16">
# <use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right">
# </use>
# </svg>
# </a>
# </div>
# </div>
# </div>

# %%
# extracting the name mileage, rating, rating count, dealer name and price of the vehicle
results[0].find("h2").get_text().strip()
# Out:
# '2020 Mercedes-Benz CLA 250 Base 4MATIC'

# %%
# mileage
results[0].find("div", {"class": "mileage"}).get_text().strip()
# Out:
# '17,266 mi.'

# %%
# rating
results[0].find("span", {"class": "sds-rating__count"}).get_text().strip()
# Out:
# '4.4'

# %%
# rating count
results[0].find("span", {"class": "sds-rating__link"}).get_text().strip()
# Out:
# '(1,396 reviews)'

# %%
# dealer name
results[0].find("div", {"class": "dealer-name"}).get_text().strip()
# Out:
# 'Mercedes-Benz of Temecula'

# %%
# price 
results[0].find("span", {"class": "primary-price"}).get_text().strip()
# Out:
# '$38,888'

# %%
# creating empty lists and using for loop to iterate
name = []
mileage = []
rating = []
rating_count = []
dealer_name = []
price = []

# name
for result in results:
    try:
        name.append(result.find("h2").get_text().strip())
    except:
        name.append("n/a")
# mileage

for result in results:
    try:
        mileage.append(result.find("div", {"class": "mileage"}).get_text().strip())
    except:
        mileage.append("n/a")
# rating

for result in results:
    try:
        rating.append(
            result.find("span", {"class": "sds-rating__count"}).get_text().strip()
        )
    except:
        rating.append("n/a")
# rating_count

for result in results:
    try:
        rating_count.append(
            result.find("span", {"class": "sds-rating__link"}).get_text().strip()
        )
    except:
        rating_count.append("n/a")
# dealer name

for result in results:
    try:
        dealer_name.append(
            result.find("div", {"class": "dealer-name"}).get_text().strip()
        )
    except:
        dealer_name.append("n/a")
# price

for result in results:
    try:
        price.append(result.find("span", {"class": "primary-price"}).get_text().strip())
    except:
        price.append("n/a")

# %%
# create pandas dataframe
car_dealer = pd.DataFrame(
    {
        "Name": name,
        "Mileage": mileage,
        "Rating": rating,
        "Rating Count": rating_count,
        "Dealer Name": dealer_name,
        "Price": price,
    }
)

car_dealer
# Out:
#                                             Name     Mileage Rating  \
# 0         2020 Mercedes-Benz CLA 250 Base 4MATIC  17,266 mi.    4.4
# 1               2021 Mercedes-Benz AMG A 35 Base   9,401 mi.    4.9
# 2        2019 Mercedes-Benz G-Class G 550 4MATIC  26,273 mi.    n/a
# 3             2021 Mercedes-Benz AMG GLE 53 Base  15,000 mi.    4.8
# 4        2020 Mercedes-Benz S-Class S 560 4MATIC  30,312 mi.    4.9
# 5      2017 Mercedes-Benz AMG GLC 43 Base 4MATIC  49,137 mi.    4.9
# 6      2017 Mercedes-Benz AMG CLA 45 Base 4MATIC  21,818 mi.    4.9
# 7        2018 Mercedes-Benz G-Class G 550 4MATIC  21,385 mi.    4.6
# 8              2022 Mercedes-Benz GLB 250 4MATIC   4,237 mi.    4.4
# 9        2021 Mercedes-Benz S-Class S 580 4MATIC   3,046 mi.    3.2
# 10       2020 Mercedes-Benz Maybach S 560 4MATIC  11,322 mi.    4.6
# 11              2018 Mercedes-Benz AMG S 65 Base  16,324 mi.    4.8
# 12            2021 Mercedes-Benz AMG GLE 53 Base  29,535 mi.    4.5
# 13               2019 Mercedes-Benz CLS 450 Base  18,717 mi.    4.2
# 14        2020 Mercedes-Benz GLS 450 Base 4MATIC  20,311 mi.    3.0
# 15        2021 Mercedes-Benz GLB 250 Base 4MATIC  19,103 mi.    4.7
# 16        2022 Mercedes-Benz GLB 250 Base 4MATIC   7,770 mi.    4.3
# 17    2021 Mercedes-Benz AMG GLC 43 4MATIC Coupe   5,533 mi.    4.8
# 18       2019 Mercedes-Benz AMG C 43 Base 4MATIC  31,818 mi.    4.4
# 19        2017 Mercedes-Benz CLS 550 Base 4MATIC  46,027 mi.    2.3
# 20  2021 Mercedes-Benz AMG GLE 63 S-Model 4MATIC   3,277 mi.    3.5
#
#        Rating Count                        Dealer Name     Price
# 0   (1,396 reviews)          Mercedes-Benz of Temecula   $38,888
# 1   (1,815 reviews)       Mercedes-Benz of San Antonio   $48,762
# 2      (13 reviews)           Mercedes-Benz of Buffalo  $144,850
# 3     (597 reviews)          Astorg Auto of Charleston   $91,995
# 4   (1,815 reviews)       Mercedes-Benz of San Antonio   $75,887
# 5   (1,815 reviews)       Mercedes-Benz of San Antonio   $43,977
# 6     (828 reviews)      Napleton Autowerks Loves Park   $37,999
# 7   (1,084 reviews)         Mercedes-Benz of Littleton  $109,999
# 8     (488 reviews)       Mercedes-Benz of Scarborough   $50,715
# 9     (233 reviews)         Mercedes-Benz of Arrowhead  $109,988
# 10    (105 reviews)       Bobby Rahal Motorcar Company  $149,880
# 11  (2,231 reviews)  Mercedes-Benz of Houston Greenway  $148,991
# 12  (2,491 reviews)   Mercedes-Benz of Fort Washington   $86,840
# 13     (83 reviews)                 Centennial Imports   $64,980
# 14    (309 reviews)   Mercedes-Benz of Milwaukee North   $71,852
# 15    (437 reviews)            Mercedes-Benz of Boerne   $43,886
# 16    (290 reviews)   Bergstrom Luxury on Victory Lane   $44,997
# 17    (958 reviews)                    Autobahn Motors   $61,996
# 18  (1,166 reviews)             Mercedes-Benz of Miami   $41,634
# 19    (205 reviews)  Baker Motor Company of Charleston   $44,998
# 20    (233 reviews)        Mercedes-Benz of New London  $126,893

# %%
# # data cleaning using lambda function to remove the reviews and brackets in the rating count column
car_dealer["Rating Count"] = car_dealer["Rating Count"].apply(
    lambda x: x.strip("reviews)").strip("(")
)

# %%
# checking data types of the columns
car_dealer.dtypes
# Out:
# Name            object
# Mileage         object
# Rating          object
# Rating Count    object
# Dealer Name     object
# Price           object
# dtype: object

# %%
# correcting the data types
car_dealer["Rating Count"] = [
    int(str(i).replace(",", "")) for i in car_dealer["Rating Count"]
]

car_dealer["Rating"] = car_dealer["Rating"].str.replace("n/a", "0").astype(float)

car_dealer
# Out:
#                                             Name     Mileage  Rating  \
# 0         2020 Mercedes-Benz CLA 250 Base 4MATIC  17,266 mi.     4.4
# 1               2021 Mercedes-Benz AMG A 35 Base   9,401 mi.     4.9
# 2        2019 Mercedes-Benz G-Class G 550 4MATIC  26,273 mi.     0.0
# 3             2021 Mercedes-Benz AMG GLE 53 Base  15,000 mi.     4.8
# 4        2020 Mercedes-Benz S-Class S 560 4MATIC  30,312 mi.     4.9
# 5      2017 Mercedes-Benz AMG GLC 43 Base 4MATIC  49,137 mi.     4.9
# 6      2017 Mercedes-Benz AMG CLA 45 Base 4MATIC  21,818 mi.     4.9
# 7        2018 Mercedes-Benz G-Class G 550 4MATIC  21,385 mi.     4.6
# 8              2022 Mercedes-Benz GLB 250 4MATIC   4,237 mi.     4.4
# 9        2021 Mercedes-Benz S-Class S 580 4MATIC   3,046 mi.     3.2
# 10       2020 Mercedes-Benz Maybach S 560 4MATIC  11,322 mi.     4.6
# 11              2018 Mercedes-Benz AMG S 65 Base  16,324 mi.     4.8
# 12            2021 Mercedes-Benz AMG GLE 53 Base  29,535 mi.     4.5
# 13               2019 Mercedes-Benz CLS 450 Base  18,717 mi.     4.2
# 14        2020 Mercedes-Benz GLS 450 Base 4MATIC  20,311 mi.     3.0
# 15        2021 Mercedes-Benz GLB 250 Base 4MATIC  19,103 mi.     4.7
# 16        2022 Mercedes-Benz GLB 250 Base 4MATIC   7,770 mi.     4.3
# 17    2021 Mercedes-Benz AMG GLC 43 4MATIC Coupe   5,533 mi.     4.8
# 18       2019 Mercedes-Benz AMG C 43 Base 4MATIC  31,818 mi.     4.4
# 19        2017 Mercedes-Benz CLS 550 Base 4MATIC  46,027 mi.     2.3
# 20  2021 Mercedes-Benz AMG GLE 63 S-Model 4MATIC   3,277 mi.     3.5
#
#     Rating Count                        Dealer Name     Price
# 0           1396          Mercedes-Benz of Temecula   $38,888
# 1           1815       Mercedes-Benz of San Antonio   $48,762
# 2             13           Mercedes-Benz of Buffalo  $144,850
# 3            597          Astorg Auto of Charleston   $91,995
# 4           1815       Mercedes-Benz of San Antonio   $75,887
# 5           1815       Mercedes-Benz of San Antonio   $43,977
# 6            828      Napleton Autowerks Loves Park   $37,999
# 7           1084         Mercedes-Benz of Littleton  $109,999
# 8            488       Mercedes-Benz of Scarborough   $50,715
# 9            233         Mercedes-Benz of Arrowhead  $109,988
# 10           105       Bobby Rahal Motorcar Company  $149,880
# 11          2231  Mercedes-Benz of Houston Greenway  $148,991
# 12          2491   Mercedes-Benz of Fort Washington   $86,840
# 13            83                 Centennial Imports   $64,980
# 14           309   Mercedes-Benz of Milwaukee North   $71,852
# 15           437            Mercedes-Benz of Boerne   $43,886
# 16           290   Bergstrom Luxury on Victory Lane   $44,997
# 17           958                    Autobahn Motors   $61,996
# 18          1166             Mercedes-Benz of Miami   $41,634
# 19           205  Baker Motor Company of Charleston   $44,998
# 20           233        Mercedes-Benz of New London  $126,893

# %%
# export to excel
car_dealer.to_excel("single_page_car.xlsx", index=False)

# %% [markdown]
# The data that has been scraped was for only one page from the url. From the cells below, we are going to scrape data from multiple pages from the url.

# %%
# creating empty lists for iteration using for loop
name = []
mileage = []
rating = []
rating_count = []
dealer_name = []
price = []

for i in range(1, 11):
    # url in a variable
    url = (
        "https://www.cars.com/shopping/results/?page="
        + str(i)
        + "&page_size=20&dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=30&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip="
    )
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.26"
    }
    
    page = requests.get(url, headers=headers)
    
    # soup object
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    
    # results
    results = soup2.find_all("div", {"class": "vehicle-card"})
    
    # name
    for result in results:
        try:
            name.append(result.find("h2").get_text().strip())
        except:
            name.append("n/a")
    
    # mileage
    for result in results:
        try:
            mileage.append(result.find("div", {"class": "mileage"}).get_text().strip())
        except:
            mileage.append("n/a")
    
    # rating
    for result in results:
        try:
            rating.append(
                result.find("span", {"class": "sds-rating__count"}).get_text().strip()
            )
        except:
            rating.append("n/a")
    
    # rating_count
    for result in results:
        try:
            rating_count.append(
                result.find("span", {"class": "sds-rating__link"}).get_text().strip()
            )
        except:
            rating_count.append("n/a")
    
    # dealer name
    for result in results:
        try:
            dealer_name.append(
                result.find("div", {"class": "dealer-name"}).get_text().strip()
            )
        except:
            dealer_name.append("n/a")
    
    # price
    for result in results:
        try:
            price.append(
                result.find("span", {"class": "primary-price"}).get_text().strip()
            )
        except:
            price.append("n/a")

# %%
# create pandas dataframe
car_dealer_combined = pd.DataFrame(
    {
        "Name": name,
        "Mileage": mileage,
        "Rating": rating,
        "Rating Count": rating_count,
        "Dealer Name": dealer_name,
        "Price": price,
    }
)

car_dealer_combined
# Out:
#                                              Name     Mileage Rating  \
# 0          2020 Mercedes-Benz CLA 250 Base 4MATIC  17,266 mi.    4.4
# 1                2021 Mercedes-Benz AMG A 35 Base   9,401 mi.    4.9
# 2              2021 Mercedes-Benz AMG GLE 53 Base  15,000 mi.    4.8
# 3         2019 Mercedes-Benz G-Class G 550 4MATIC  26,273 mi.    n/a
# 4         2020 Mercedes-Benz S-Class S 560 4MATIC  30,312 mi.    4.9
# ..                                            ...         ...    ...
# 201        2020 Mercedes-Benz GLS 450 Base 4MATIC  34,630 mi.    4.8
# 202  2018 Mercedes-Benz AMG GLE 63 S Coupe 4MATIC  15,886 mi.    4.1
# 203        2022 Mercedes-Benz GLC 300 Base 4MATIC   6,874 mi.    4.8
# 204     2019 Mercedes-Benz AMG GLC 43 Base 4MATIC  29,391 mi.    4.6
# 205              2019 Mercedes-Benz C-Class C 300  18,993 mi.    4.8
#
#         Rating Count                    Dealer Name     Price
# 0    (1,396 reviews)      Mercedes-Benz of Temecula   $38,888
# 1    (1,815 reviews)   Mercedes-Benz of San Antonio   $48,762
# 2      (597 reviews)      Astorg Auto of Charleston   $91,995
# 3       (13 reviews)       Mercedes-Benz of Buffalo  $144,850
# 4    (1,815 reviews)   Mercedes-Benz of San Antonio   $75,887
# ..               ...                            ...       ...
# 201     (70 reviews)  Mercedes-Benz of West Houston   $71,990
# 202  (1,017 reviews)                 RBM of Atlanta   $83,919
# 203  (1,238 reviews)   Mercedes-Benz of North Haven   $52,375
# 204  (1,084 reviews)     Mercedes-Benz of Littleton   $49,999
# 205    (196 reviews)          Mercedes-Benz of Maui   $33,881
#
# [206 rows x 6 columns]

# %%
# check for duplicates
car_dealer_combined.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# Length: 206, dtype: bool

# %%
# data cleaning using lambda function to remove the reviews and brackets in the rating count column
car_dealer_combined["Rating Count"] = car_dealer_combined["Rating Count"].apply(
    lambda x: x.strip("reviews)").strip("(")
)

# %%
# checking data types
car_dealer_combined.dtypes
# Out:
# Name            object
# Mileage         object
# Rating          object
# Rating Count    object
# Dealer Name     object
# Price           object
# dtype: object

# %%
# correcting data types
car_dealer_combined["Rating Count"] = [
    int(str(i).replace(",", "")) for i in car_dealer_combined["Rating Count"]
]

car_dealer_combined["Rating"] = (
    car_dealer_combined["Rating"].str.replace("n/a", "0").astype(float)
)

# %%
car_dealer_combined
# Out:
#                                              Name     Mileage  Rating  \
# 0          2020 Mercedes-Benz CLA 250 Base 4MATIC  17,266 mi.     4.4
# 1                2021 Mercedes-Benz AMG A 35 Base   9,401 mi.     4.9
# 2              2021 Mercedes-Benz AMG GLE 53 Base  15,000 mi.     4.8
# 3         2019 Mercedes-Benz G-Class G 550 4MATIC  26,273 mi.     0.0
# 4         2020 Mercedes-Benz S-Class S 560 4MATIC  30,312 mi.     4.9
# ..                                            ...         ...     ...
# 201        2020 Mercedes-Benz GLS 450 Base 4MATIC  34,630 mi.     4.8
# 202  2018 Mercedes-Benz AMG GLE 63 S Coupe 4MATIC  15,886 mi.     4.1
# 203        2022 Mercedes-Benz GLC 300 Base 4MATIC   6,874 mi.     4.8
# 204     2019 Mercedes-Benz AMG GLC 43 Base 4MATIC  29,391 mi.     4.6
# 205              2019 Mercedes-Benz C-Class C 300  18,993 mi.     4.8
#
#      Rating Count                    Dealer Name     Price
# 0            1396      Mercedes-Benz of Temecula   $38,888
# 1            1815   Mercedes-Benz of San Antonio   $48,762
# 2             597      Astorg Auto of Charleston   $91,995
# 3              13       Mercedes-Benz of Buffalo  $144,850
# 4            1815   Mercedes-Benz of San Antonio   $75,887
# ..            ...                            ...       ...
# 201            70  Mercedes-Benz of West Houston   $71,990
# 202          1017                 RBM of Atlanta   $83,919
# 203          1238   Mercedes-Benz of North Haven   $52,375
# 204          1084     Mercedes-Benz of Littleton   $49,999
# 205           196          Mercedes-Benz of Maui   $33,881
#
# [206 rows x 6 columns]

# %%
# export to excel
car_dealer_combined.to_excel("multiple_page_car.xlsx", index=False)
